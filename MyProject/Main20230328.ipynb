# %%
class customer:
    pass

class car:
    global car_index 
    car_index = 1
    
    # constructor: this is a type of function that gets executed implicitly while the object creation
    
    def __init__(self):
        self.cars = list()
        
        
    # status=1 : Car is available , 0 : Car is not available
    # number_of_cars : the number of cars to add , default = 1 
    def add_cars(self,make,model,year,price,numberofcars=1,status=1):
        #global car_index 

        ## car_id calculates from 1 for each car object 
        if len(self.cars) == 0 :
            car_id = 1
        else:
            car_id = max(self.cars,key=lambda item:item[0]) [0] + 1 
    
        for i in range(car_id , numberofcars+car_id):
        
       # for i in range(numberofcars):
            self.cars.append((i,make,model,year,price,status))   
       #     car_index = car_index + 1
    
    
    ## Display all cars
    def display_all_cars(self):
        return self.cars
    
    ## Display those which are available - not rented
    def display_available_cars(self):
        return list(filter(lambda item:item[5]==1,self.cars))
        
class rental_system:
    pass

class employee:
    pass

# %%
CarsForRent = car()
CarsForRent.add_cars('Toyota','Lexux',2020,35000,5)
CarsForRent.add_cars('Toyota','Lexux',2021,37000,4)
CarsForRent.add_cars('Toyota','Lexux',2022,41000,5)
CarsForRent.add_cars('Toyota','CHR',2019,32000,1)
CarsForRent.add_cars('Toyota','CHR',2022,34000,10)
CarsForRent.add_cars('Toyota','CHR',2023,36000,12)
CarsForRent.add_cars('Toyota','Corolla',2020,32000,3)
CarsForRent.add_cars('Toyota','Corolla',2020,34000,3)
CarsForRent.add_cars('Toyota','Venza',2021,35000,5)
CarsForRent.add_cars('Toyota','Venza',2022,40000,5)

CarsForRent.add_cars('Mazda','Mazda3',2018,28000,12)
CarsForRent.add_cars('Mazda','Mazda3',2019,32000,5)
CarsForRent.add_cars('Mazda','CX5',2020,38000,2)
CarsForRent.add_cars('Mazda','CX5',2021,40000,3)

CarsForRent.add_cars('Honda','Civic',2018,28000,12)
CarsForRent.add_cars('Honda','Civic',2019,32000,5)
CarsForRent.add_cars('Honda','Accord',2020,38000,10)
CarsForRent.add_cars('Honda','Accord',2021,40000,15)

# %%
CarsForRent.display_all_cars()
CarsForRent.display_available_cars()
# Out:
# [(1, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (2, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (3, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (4, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (5, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (6, 'Toyota', 'Lexux', 2021, 37000, 1),
#  (7, 'Toyota', 'Lexux', 2021, 37000, 1),
#  (8, 'Toyota', 'Lexux', 2021, 37000, 1),
#  (9, 'Toyota', 'Lexux', 2021, 37000, 1),
#  (10, 'Toyota', 'Lexux', 2022, 41000, 1),
#  (11, 'Toyota', 'Lexux', 2022, 41000, 1),
#  (12, 'Toyota', 'Lexux', 2022, 41000, 1),
#  (13, 'Toyota', 'Lexux', 2022, 41000, 1),
#  (14, 'Toyota', 'Lexux', 2022, 41000, 1),
#  (15, 'Toyota', 'CHR', 2019, 32000, 1),
#  (16, 'Toyota', 'CHR', 2022, 34000, 1),
#  (17, 'Toyota', 'CHR', 2022, 34000, 1),
#  (18, 'Toyota', 'CHR', 2022, 34000, 1),
#  (19, 'Toyota', 'CHR', 2022, 34000, 1),
#  (20, 'Toyota', 'CHR', 2022, 34000, 1),
#  (21, 'Toyota', 'CHR', 2022, 34000, 1),
#  (22, 'Toyota', 'CHR', 2022, 34000, 1),
#  (23, 'Toyota', 'CHR', 2022, 34000, 1),
#  (24, 'Toyota', 'CHR', 2022, 34000, 1),
#  (25, 'Toyota', 'CHR', 2022, 34000, 1),
#  (26, 'Toyota', 'CHR', 2023, 36000, 1),
#  (27, 'Toyota', 'CHR', 2023, 36000, 1),
#  (28, 'Toyota', 'CHR', 2023, 36000, 1),
#  (29, 'Toyota', 'CHR', 2023, 36000, 1),
#  (30, 'Toyota', 'CHR', 2023, 36000, 1),
#  (31, 'Toyota', 'CHR', 2023, 36000, 1),
#  (32, 'Toyota', 'CHR', 2023, 36000, 1),
#  (33, 'Toyota', 'CHR', 2023, 36000, 1),
#  (34, 'Toyota', 'CHR', 2023, 36000, 1),
#  (35, 'Toyota', 'CHR', 2023, 36000, 1),
#  (36, 'Toyota', 'CHR', 2023, 36000, 1),
#  (37, 'Toyota', 'CHR', 2023, 36000, 1),
#  (38, 'Toyota', 'Corolla', 2020, 32000, 1),
#  (39, 'Toyota', 'Corolla', 2020, 32000, 1),
#  (40, 'Toyota', 'Corolla', 2020, 32000, 1),
#  (41, 'Toyota', 'Corolla', 2020, 34000, 1),
#  (42, 'Toyota', 'Corolla', 2020, 34000, 1),
#  (43, 'Toyota', 'Corolla', 2020, 34000, 1),
#  (44, 'Toyota', 'Venza', 2021, 35000, 1),
#  (45, 'Toyota', 'Venza', 2021, 35000, 1),
#  (46, 'Toyota', 'Venza', 2021, 35000, 1),
#  (47, 'Toyota', 'Venza', 2021, 35000, 1),
#  (48, 'Toyota', 'Venza', 2021, 35000, 1),
#  (49, 'Toyota', 'Venza', 2022, 40000, 1),
#  (50, 'Toyota', 'Venza', 2022, 40000, 1),
#  (51, 'Toyota', 'Venza', 2022, 40000, 1),
#  (52, 'Toyota', 'Venza', 2022, 40000, 1),
#  (53, 'Toyota', 'Venza', 2022, 40000, 1),
#  (54, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (55, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (56, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (57, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (58, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (59, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (60, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (61, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (62, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (63, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (64, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (65, 'Mazda', 'Mazda3', 2018, 28000, 1),
#  (66, 'Mazda', 'Mazda3', 2019, 32000, 1),
#  (67, 'Mazda', 'Mazda3', 2019, 32000, 1),
#  (68, 'Mazda', 'Mazda3', 2019, 32000, 1),
#  (69, 'Mazda', 'Mazda3', 2019, 32000, 1),
#  (70, 'Mazda', 'Mazda3', 2019, 32000, 1),
#  (71, 'Mazda', 'CX5', 2020, 38000, 1),
#  (72, 'Mazda', 'CX5', 2020, 38000, 1),
#  (73, 'Mazda', 'CX5', 2021, 40000, 1),
#  (74, 'Mazda', 'CX5', 2021, 40000, 1),
#  (75, 'Mazda', 'CX5', 2021, 40000, 1),
#  (76, 'Honda', 'Civic', 2018, 28000, 1),
#  (77, 'Honda', 'Civic', 2018, 28000, 1),
#  (78, 'Honda', 'Civic', 2018, 28000, 1),
#  (79, 'Honda', 'Civic', 2018, 28000, 1),
#  (80, 'Honda', 'Civic', 2018, 28000, 1),
#  (81, 'Honda', 'Civic', 2018, 28000, 1),
#  (82, 'Honda', 'Civic', 2018, 28000, 1),
#  (83, 'Honda', 'Civic', 2018, 28000, 1),
#  (84, 'Honda', 'Civic', 2018, 28000, 1),
#  (85, 'Honda', 'Civic', 2018, 28000, 1),
#  (86, 'Honda', 'Civic', 2018, 28000, 1),
#  (87, 'Honda', 'Civic', 2018, 28000, 1),
#  (88, 'Honda', 'Civic', 2019, 32000, 1),
#  (89, 'Honda', 'Civic', 2019, 32000, 1),
#  (90, 'Honda', 'Civic', 2019, 32000, 1),
#  (91, 'Honda', 'Civic', 2019, 32000, 1),
#  (92, 'Honda', 'Civic', 2019, 32000, 1),
#  (93, 'Honda', 'Accord', 2020, 38000, 1),
#  (94, 'Honda', 'Accord', 2020, 38000, 1),
#  (95, 'Honda', 'Accord', 2020, 38000, 1),
#  (96, 'Honda', 'Accord', 2020, 38000, 1),
#  (97, 'Honda', 'Accord', 2020, 38000, 1),
#  (98, 'Honda', 'Accord', 2020, 38000, 1),
#  (99, 'Honda', 'Accord', 2020, 38000, 1),
#  (100, 'Honda', 'Accord', 2020, 38000, 1),
#  (101, 'Honda', 'Accord', 2020, 38000, 1),
#  (102, 'Honda', 'Accord', 2020, 38000, 1),
#  (103, 'Honda', 'Accord', 2021, 40000, 1),
#  (104, 'Honda', 'Accord', 2021, 40000, 1),
#  (105, 'Honda', 'Accord', 2021, 40000, 1),
#  (106, 'Honda', 'Accord', 2021, 40000, 1),
#  (107, 'Honda', 'Accord', 2021, 40000, 1),
#  (108, 'Honda', 'Accord', 2021, 40000, 1),
#  (109, 'Honda', 'Accord', 2021, 40000, 1),
#  (110, 'Honda', 'Accord', 2021, 40000, 1),
#  (111, 'Honda', 'Accord', 2021, 40000, 1),
#  (112, 'Honda', 'Accord', 2021, 40000, 1),
#  (113, 'Honda', 'Accord', 2021, 40000, 1),
#  (114, 'Honda', 'Accord', 2021, 40000, 1),
#  (115, 'Honda', 'Accord', 2021, 40000, 1),
#  (116, 'Honda', 'Accord', 2021, 40000, 1),
#  (117, 'Honda', 'Accord', 2021, 40000, 1)]

# %%
mazda.display_all_cars()
mazda.display_available_cars()
# Out:
# [(29, 'mazda', 'mazda3', 2022, 28000, 1),
#  (30, 'mazda', 'mazda7', 2023, 45000, 1),
#  (31, 'mazda', 'mazda7', 2023, 45000, 1),
#  (32, 'mazda', 'mazda7', 2023, 45000, 1),
#  (33, 'mazda', 'mazda7', 2023, 45000, 1),
#  (34, 'mazda', 'mazda7', 2023, 45000, 1),
#  (35, 'mazda', 'mazda7', 2023, 45000, 1),
#  (36, 'mazda', 'mazda7', 2023, 45000, 1)]
