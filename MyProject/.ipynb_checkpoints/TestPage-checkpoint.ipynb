# %%
class CarRental:
    #global car_index 
    #car_index = 1
    global selected_brand 
    global selected_model
    global selected_year
    
    # constructor: this is a type of function that gets executed implicitly while the object creation
    
    def __init__(self):
        self.cars = list()
       
        
    # status=1 : Car is available , 0 : Car is not available
    # number_of_cars : the number of cars to add , default = 1 
    def add_cars(self,make,model,year,price,numberofcars=1,status=1):
        #global car_index 

        ## car_id calculates from 1 for each car object 
        if len(self.cars) == 0 :
            car_id = 1
        else:
            car_id = max(self.cars,key=lambda item:item[0]) [0] + 1 
    
        for i in range(car_id , numberofcars+car_id):
        
       # for i in range(numberofcars):
            self.cars.append((i,make,model,year,price,status))   
       #     car_index = car_index + 1
    
    
    ## Display all cars
    def display_all_cars(self):
        return self.cars
    
    ## Display those which are available - not rented
    def display_available_cars(self):
        return list(filter(lambda item:item[5]==1,self.cars))
        
       
    def let_user_pick(self,item_to_pick):
        global selected_brand 
        global selected_model
        global selected_year
        # match is supported in Python 10, so I need to update Python in order to use it
        #match item_to_pick:
        #   case 'make':
        #       print("make")
        #    case 'model':
        #        print("model")
        #    case 'year':
        #        print("year")
        if item_to_pick == 'make':
            message = "Which brand would you like to rent?"
            list_item = 1
            list_of_available_cars_by_item = list((filter(lambda item:item[5]==1,self.cars)))
            
            
        elif item_to_pick == 'model':
            message = "Which model would you like to rent?"
            list_item = 2
            list_of_available_cars_by_item = list((filter(lambda item:item[5]==1 and item[1]==selected_brand ,self.cars)))

        else:
            message = ("Please choose the year?")
            list_item = 3
            list_of_available_cars_by_item = list((filter(lambda item:item[5]==1 and item[1]==selected_brand and item[2]==selected_model,self.cars)))
   
        print(message)
        print(list_of_available_cars_by_item)
          
        list_of_available_cars = list((filter(lambda item:item[5]==1,self.cars)))
        items_to_choose = set([item[list_item] for item in list_of_available_cars_by_item])
         
        for id,val in enumerate(items_to_choose):
            print("{}.{}".format(id,val))
            
        users_answer=999999   

        while users_answer > len(items_to_choose)-1 or  users_answer < 0 :
            users_answer = int(input("Please pick from the list: "))

        if item_to_pick == 'make':
            selected_brand = list(items_to_choose)[users_answer]
            
        elif item_to_pick == 'model':
            selected_model = list(items_to_choose)[users_answer]
        else:
            selected_year = list(items_to_choose)[users_answer]
         
         
            
       #print(list(items_to_choose)[users_answer])

        
        
    def display_available_cars_for_rent(self):
        import inquirer as iq
        
        questions = [iq.List('make' , message = "Which brand would you like to rent?" , choices=['22','33'])]
        answers = iq.prompt(questions)
        print(answers["make"])
        

    def display_rent_types(self):
        print("""
        1.Rent a car on hourly basis costs $5
        2.Rent a car on daily  basis costs $20
        3.Rent a car on weekly basis costs $60
        """)
        
        
    
    def selected_car_for_rent(self,number_of_cars):
        selected_car = {"brand":selected_brand , "model":selected_model , "year" :selected_year , "number_of_cars":number_of_cars }
        return (selected_car)
        
    
     def check_availability(self,selected_car):
        print( list((filter(lambda item:item[1]==selected_car('make') and item[2]==selected_car('model'),item[3]==selected_car('year') ,self.cars))))
        if True :
            return True
        else:
            return False
        
        
    def Update_stock(self,selected_car):
        pass
        
        
    def return_car(self):
        print("return car")
        
class Customer():
    print("I am a customer")
# Out:
# I am a customer

# %%
    CanCarRental = CarRental()
    CanCarRental.add_cars('Toyota','Lexux',2020,35000,5)
    CanCarRental.add_cars('Toyota','Lexux',2021,37000,4)
    CanCarRental.add_cars('Toyota','Lexux',2022,41000,5)
    CanCarRental.add_cars('Toyota','CHR',2019,32000,1)
    CanCarRental.add_cars('Toyota','CHR',2022,34000,10)
    CanCarRental.add_cars('Toyota','CHR',2023,36000,12)
    CanCarRental.add_cars('Toyota','Corolla',2020,32000,3)
    CanCarRental.add_cars('Toyota','Corolla',2020,34000,3)
    CanCarRental.add_cars('Toyota','Venza',2021,35000,5)
    CanCarRental.add_cars('Toyota','Venza',2022,40000,5)

    CanCarRental.add_cars('Mazda','Mazda3',2018,28000,12)
    CanCarRental.add_cars('Mazda','Mazda3',2019,32000,5)
    CanCarRental.add_cars('Mazda','CX5',2020,38000,2)
    CanCarRental.add_cars('Mazda','CX5',2021,40000,3)

    CanCarRental.add_cars('Honda','Civic',2018,28000,12)
    CanCarRental.add_cars('Honda','Civic',2019,32000,5)
    CanCarRental.add_cars('Honda','Accord',2020,38000,10)

# %%
CanCarRental.let_user_pick('make')
CanCarRental.let_user_pick('model')
CanCarRental.let_user_pick('year')
# Out:
# Which brand would you like to rent?
# [(1, 'Toyota', 'Lexux', 2020, 35000, 1), (2, 'Toyota', 'Lexux', 2020, 35000, 1), (3, 'Toyota', 'Lexux', 2020, 35000, 1), (4, 'Toyota', 'Lexux', 2020, 35000, 1), (5, 'Toyota', 'Lexux', 2020, 35000, 1), (6, 'Toyota', 'Lexux', 2021, 37000, 1), (7, 'Toyota', 'Lexux', 2021, 37000, 1), (8, 'Toyota', 'Lexux', 2021, 37000, 1), (9, 'Toyota', 'Lexux', 2021, 37000, 1), (10, 'Toyota', 'Lexux', 2022, 41000, 1), (11, 'Toyota', 'Lexux', 2022, 41000, 1), (12, 'Toyota', 'Lexux', 2022, 41000, 1), (13, 'Toyota', 'Lexux', 2022, 41000, 1), (14, 'Toyota', 'Lexux', 2022, 41000, 1), (15, 'Toyota', 'CHR', 2019, 32000, 1), (16, 'Toyota', 'CHR', 2022, 34000, 1), (17, 'Toyota', 'CHR', 2022, 34000, 1), (18, 'Toyota', 'CHR', 2022, 34000, 1), (19, 'Toyota', 'CHR', 2022, 34000, 1), (20, 'Toyota', 'CHR', 2022, 34000, 1), (21, 'Toyota', 'CHR', 2022, 34000, 1), (22, 'Toyota', 'CHR', 2022, 34000, 1), (23, 'Toyota', 'CHR', 2022, 34000, 1), (24, 'Toyota', 'CHR', 2022, 34000, 1), (25, 'Toyota', 'CHR', 2022, 34000, 1), (26, 'Toyota', 'CHR', 2023, 36000, 1), (27, 'Toyota', 'CHR', 2023, 36000, 1), (28, 'Toyota', 'CHR', 2023, 36000, 1), (29, 'Toyota', 'CHR', 2023, 36000, 1), (30, 'Toyota', 'CHR', 2023, 36000, 1), (31, 'Toyota', 'CHR', 2023, 36000, 1), (32, 'Toyota', 'CHR', 2023, 36000, 1), (33, 'Toyota', 'CHR', 2023, 36000, 1), (34, 'Toyota', 'CHR', 2023, 36000, 1), (35, 'Toyota', 'CHR', 2023, 36000, 1), (36, 'Toyota', 'CHR', 2023, 36000, 1), (37, 'Toyota', 'CHR', 2023, 36000, 1), (38, 'Toyota', 'Corolla', 2020, 32000, 1), (39, 'Toyota', 'Corolla', 2020, 32000, 1), (40, 'Toyota', 'Corolla', 2020, 32000, 1), (41, 'Toyota', 'Corolla', 2020, 34000, 1), (42, 'Toyota', 'Corolla', 2020, 34000, 1), (43, 'Toyota', 'Corolla', 2020, 34000, 1), (44, 'Toyota', 'Venza', 2021, 35000, 1), (45, 'Toyota', 'Venza', 2021, 35000, 1), (46, 'Toyota', 'Venza', 2021, 35000, 1), (47, 'Toyota', 'Venza', 2021, 35000, 1), (48, 'Toyota', 'Venza', 2021, 35000, 1), (49, 'Toyota', 'Venza', 2022, 40000, 1), (50, 'Toyota', 'Venza', 2022, 40000, 1), (51, 'Toyota', 'Venza', 2022, 40000, 1), (52, 'Toyota', 'Venza', 2022, 40000, 1), (53, 'Toyota', 'Venza', 2022, 40000, 1), (54, 'Mazda', 'Mazda3', 2018, 28000, 1), (55, 'Mazda', 'Mazda3', 2018, 28000, 1), (56, 'Mazda', 'Mazda3', 2018, 28000, 1), (57, 'Mazda', 'Mazda3', 2018, 28000, 1), (58, 'Mazda', 'Mazda3', 2018, 28000, 1), (59, 'Mazda', 'Mazda3', 2018, 28000, 1), (60, 'Mazda', 'Mazda3', 2018, 28000, 1), (61, 'Mazda', 'Mazda3', 2018, 28000, 1), (62, 'Mazda', 'Mazda3', 2018, 28000, 1), (63, 'Mazda', 'Mazda3', 2018, 28000, 1), (64, 'Mazda', 'Mazda3', 2018, 28000, 1), (65, 'Mazda', 'Mazda3', 2018, 28000, 1), (66, 'Mazda', 'Mazda3', 2019, 32000, 1), (67, 'Mazda', 'Mazda3', 2019, 32000, 1), (68, 'Mazda', 'Mazda3', 2019, 32000, 1), (69, 'Mazda', 'Mazda3', 2019, 32000, 1), (70, 'Mazda', 'Mazda3', 2019, 32000, 1), (71, 'Mazda', 'CX5', 2020, 38000, 1), (72, 'Mazda', 'CX5', 2020, 38000, 1), (73, 'Mazda', 'CX5', 2021, 40000, 1), (74, 'Mazda', 'CX5', 2021, 40000, 1), (75, 'Mazda', 'CX5', 2021, 40000, 1), (76, 'Honda', 'Civic', 2018, 28000, 1), (77, 'Honda', 'Civic', 2018, 28000, 1), (78, 'Honda', 'Civic', 2018, 28000, 1), (79, 'Honda', 'Civic', 2018, 28000, 1), (80, 'Honda', 'Civic', 2018, 28000, 1), (81, 'Honda', 'Civic', 2018, 28000, 1), (82, 'Honda', 'Civic', 2018, 28000, 1), (83, 'Honda', 'Civic', 2018, 28000, 1), (84, 'Honda', 'Civic', 2018, 28000, 1), (85, 'Honda', 'Civic', 2018, 28000, 1), (86, 'Honda', 'Civic', 2018, 28000, 1), (87, 'Honda', 'Civic', 2018, 28000, 1), (88, 'Honda', 'Civic', 2019, 32000, 1), (89, 'Honda', 'Civic', 2019, 32000, 1), (90, 'Honda', 'Civic', 2019, 32000, 1), (91, 'Honda', 'Civic', 2019, 32000, 1), (92, 'Honda', 'Civic', 2019, 32000, 1), (93, 'Honda', 'Accord', 2020, 38000, 1), (94, 'Honda', 'Accord', 2020, 38000, 1), (95, 'Honda', 'Accord', 2020, 38000, 1), (96, 'Honda', 'Accord', 2020, 38000, 1), (97, 'Honda', 'Accord', 2020, 38000, 1), (98, 'Honda', 'Accord', 2020, 38000, 1), (99, 'Honda', 'Accord', 2020, 38000, 1), (100, 'Honda',  ...
# 0.Mazda
# 1.Honda
# 2.Toyota
# Please pick from the list: 1
# Which model would you like to rent?
# [(76, 'Honda', 'Civic', 2018, 28000, 1), (77, 'Honda', 'Civic', 2018, 28000, 1), (78, 'Honda', 'Civic', 2018, 28000, 1), (79, 'Honda', 'Civic', 2018, 28000, 1), (80, 'Honda', 'Civic', 2018, 28000, 1), (81, 'Honda', 'Civic', 2018, 28000, 1), (82, 'Honda', 'Civic', 2018, 28000, 1), (83, 'Honda', 'Civic', 2018, 28000, 1), (84, 'Honda', 'Civic', 2018, 28000, 1), (85, 'Honda', 'Civic', 2018, 28000, 1), (86, 'Honda', 'Civic', 2018, 28000, 1), (87, 'Honda', 'Civic', 2018, 28000, 1), (88, 'Honda', 'Civic', 2019, 32000, 1), (89, 'Honda', 'Civic', 2019, 32000, 1), (90, 'Honda', 'Civic', 2019, 32000, 1), (91, 'Honda', 'Civic', 2019, 32000, 1), (92, 'Honda', 'Civic', 2019, 32000, 1), (93, 'Honda', 'Accord', 2020, 38000, 1), (94, 'Honda', 'Accord', 2020, 38000, 1), (95, 'Honda', 'Accord', 2020, 38000, 1), (96, 'Honda', 'Accord', 2020, 38000, 1), (97, 'Honda', 'Accord', 2020, 38000, 1), (98, 'Honda', 'Accord', 2020, 38000, 1), (99, 'Honda', 'Accord', 2020, 38000, 1), (100, 'Honda', 'Accord', 2020, 38000, 1), (101, 'Honda', 'Accord', 2020, 38000, 1), (102, 'Honda', 'Accord', 2020, 38000, 1)]
# 0.Civic
# 1.Accord
# Please pick from the list: 1
# Please choose the year?
# [(93, 'Honda', 'Accord', 2020, 38000, 1), (94, 'Honda', 'Accord', 2020, 38000, 1), (95, 'Honda', 'Accord', 2020, 38000, 1), (96, 'Honda', 'Accord', 2020, 38000, 1), (97, 'Honda', 'Accord', 2020, 38000, 1), (98, 'Honda', 'Accord', 2020, 38000, 1), (99, 'Honda', 'Accord', 2020, 38000, 1), (100, 'Honda', 'Accord', 2020, 38000, 1), (101, 'Honda', 'Accord', 2020, 38000, 1), (102, 'Honda', 'Accord', 2020, 38000, 1)]
# 0.2020
# Please pick from the list: 1
# Please pick from the list: 0
