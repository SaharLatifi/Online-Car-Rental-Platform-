# %%
from CarRental import CarRental,Customer

def main():
    global CanCarRental 
    CanCarRental = CarRental()
    global Customer
    Customer= Customer("Walt","Disney")
      
    initialize()
   
   

    while True:
        print("""
        -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
        How can we help you?
        1.Display all cars.
        2.Display all available cars.
        3.Display all type of rents.
        4.Rent a car.
        5.Return a car.
        6.Exit.
        """)
        
        choice = input("Enter your choice:")
        
        try:
            choice=int(choice)
            if choice > 6 or choice < 1 :
                raise Exception("Please enter a number between 1 and 6.")
        except ValueError:
            print("Please enter a number")
            continue
        except Exception:
            print("Please enter a number between 1 and 6.")
            continue
        if choice == 1:
            print("You can find all the cars listed below:")
            print("======================================")
            print(*(CanCarRental.display_all_cars()),sep='\n')
        if choice == 2:
            print("This is a list of all available cars to rent:")
            print("=============================================")
            print(*(CanCarRental.display_available_cars()),sep='\n')
        elif choice == 3:
            print("The following methods are available for renting:")
            print("================================================")
            CanCarRental.display_rent_types()
        elif choice == 4:
            rent_car()
                
     
        elif choice == 5 :
            return_car()
        elif choice == 6 :
            break
        else:
            print("Please enter a number between 1 and 6.")
        

def rent_car():
    global Customer
    
    ######
    CanCarRental.display_rent_types()
    while True:
        Customer.rental_basis = input("How would you like to rent?")
        try:
            Customer.rental_basis=int(Customer.rental_basis)
            if Customer.rental_basis <= 0 or Customer.rental_basis > 3 :
                raise Exception("Please enter a valid number.")
        except ValueError:
            print("Please enter a valid number.")
            continue
        except Exception:
            print("Please enter a valid number.")
            continue
        else:
            break  
    ######
    
    #print(Customer.rental_basis)
    CanCarRental.let_user_pick('make')
    CanCarRental.let_user_pick('model')
    CanCarRental.let_user_pick('year')
    
    while True:
        number_of_cars = input("How many cars would you like to rent?")
        try:
            number_of_cars=int(number_of_cars)
            if number_of_cars <= 0 :
                raise Exception("Please enter a valid number.")
        except ValueError:
            print("Please enter a valid number.")
            continue
        except Exception:
            print("Please enter a valid number.")
            continue
        else:
            break  
    
    
    selected_car = CanCarRental.selected_car_for_rent(number_of_cars)
    selected_car
     
    current_stock = CanCarRental.check_availability(selected_car)
    #print(current_stock)
    #print("customer")
    #print(Customer.f_name + " " + Customer.l_name)
    #print(Customer.cars)
    if current_stock < number_of_cars :
        print("Only {} cars are available.".format(current_stock),sep="\n")
    else:
        CanCarRental.rent_car(selected_car , 1,Customer)
        print("\n ***** Thank you {} for renting with us! *****".format(Customer.f_name + ' ' + Customer.l_name))


    #print(Customer.cars)
    #print(Customer.rent_datetime)
    
    
def return_car():
    print(Customer.rental_basis)
    while True:
        print("""
        1.Return the car by Car_Id.
        2.Return all.
        3.Exit.
        """)
        
        choice = input("Enter your choice:")
        
        try:
            choice=int(choice)
            if choice > 3 or choice < 1 :
                raise Exception("Please enter a number between 1 and 3.")
        except ValueError:
            print("Please enter a number between 1 and 3.")
            continue
        except Exception:
            print("Please enter a number between 1 and 3.")
            continue
        if choice == 1:
            car_id = input("Enter the car_id")
            try:
                car_id =int(car_id)
            except ValueError:
                print("Please enter a valid car_id")
                continue
            CanCarRental.issue_bill(Customer,car_id)
            CanCarRental.return_car(Customer,car_id)

        if choice == 2:
            CanCarRental.issue_bill(Customer)
            CanCarRental.return_car(Customer)
        elif choice == 3:
            return False

 
        
    
        
        
def initialize():
     
    CanCarRental.add_cars('Toyota','Lexus',2020,35000,3)
    CanCarRental.add_cars('Toyota','Lexus',2021,37000,2)
    CanCarRental.add_cars('Toyota','CHR',2022,34000,4)
    CanCarRental.add_cars('Toyota','CHR',2023,36000,3)
    CanCarRental.add_cars('Toyota','Corolla',2020,32000,3)
    CanCarRental.add_cars('Toyota','Venza',2021,35000,5)

    CanCarRental.add_cars('Mazda','Mazda3',2018,28000,3)
    CanCarRental.add_cars('Mazda','Mazda3',2019,32000,5)
    CanCarRental.add_cars('Mazda','CX5',2021,40000,3)

    CanCarRental.add_cars('Honda','Civic',2018,28000,2)
    CanCarRental.add_cars('Honda','Civic',2019,32000,3)
    CanCarRental.add_cars('Honda','Accord',2020,38000,4)

  
    
  

if __name__=="__main__":
    main()
# Out:
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:4
#
#         1.Rent a car on hourly basis costs $5
#         2.Rent a car on daily  basis costs $20
#         3.Rent a car on weekly basis costs $60
#
# How would you like to rent?1
# Which brand would you like to rent?
# 0.Toyota
# 1.Honda
# 2.Mazda
# Please pick from the list: 0
# Which model would you like to rent?
# 0.Lexus
# 1.Corolla
# 2.CHR
# 3.Venza
# Please pick from the list: 0
# Please choose the year?
# 0.2020
# 1.2021
# Please pick from the list: 0
# How many cars would you like to rent?2
#
#  ***** Thank you Walt Disney for renting with us! *****
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:5
# 1
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:2
#
#  *****  Thank you Walt Disney for being a loyal customer. *****
# Here is your bill:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#  RentDate  :2023-03-23 00:15:39.129981
#  ReturDate :2023-04-01 20:05:39.545483
#  RentalBasis :Hourly
#  Number of cars: 2
#  Total payment:2360
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:3
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:1
# You can find all the cars listed below:
# ======================================
# (1, 'Toyota', 'Lexus', 2020, 35000, 1)
# (2, 'Toyota', 'Lexus', 2020, 35000, 1)
# (3, 'Toyota', 'Lexus', 2020, 35000, 1)
# (4, 'Toyota', 'Lexus', 2021, 37000, 1)
# (5, 'Toyota', 'Lexus', 2021, 37000, 1)
# (6, 'Toyota', 'CHR', 2022, 34000, 1)
# (7, 'Toyota', 'CHR', 2022, 34000, 1)
# (8, 'Toyota', 'CHR', 2022, 34000, 1)
# (9, 'Toyota', 'CHR', 2022, 34000, 1)
# (10, 'Toyota', 'CHR', 2023, 36000, 1)
# (11, 'Toyota', 'CHR', 2023, 36000, 1)
# (12, 'Toyota', 'CHR', 2023, 36000, 1)
# (13, 'Toyota', 'Corolla', 2020, 32000, 1)
# (14, 'Toyota', 'Corolla', 2020, 32000, 1)
# (15, 'Toyota', 'Corolla', 2020, 32000, 1)
# (16, 'Toyota', 'Venza', 2021, 35000, 1)
# (17, 'Toyota', 'Venza', 2021, 35000, 1)
# (18, 'Toyota', 'Venza', 2021, 35000, 1)
# (19, 'Toyota', 'Venza', 2021, 35000, 1)
# (20, 'Toyota', 'Venza', 2021, 35000, 1)
# (21, 'Mazda', 'Mazda3', 2018, 28000, 1)
# (22, 'Mazda', 'Mazda3', 2018, 28000, 1)
# (23, 'Mazda', 'Mazda3', 2018, 28000, 1)
# (24, 'Mazda', 'Mazda3', 2019, 32000, 1)
# (25, 'Mazda', 'Mazda3', 2019, 32000, 1)
# (26, 'Mazda', 'Mazda3', 2019, 32000, 1)
# (27, 'Mazda', 'Mazda3', 2019, 32000, 1)
# (28, 'Mazda', 'Mazda3', 2019, 32000, 1)
# (29, 'Mazda', 'CX5', 2021, 40000, 1)
# (30, 'Mazda', 'CX5', 2021, 40000, 1)
# (31, 'Mazda', 'CX5', 2021, 40000, 1)
# (32, 'Honda', 'Civic', 2018, 28000, 1)
# (33, 'Honda', 'Civic', 2018, 28000, 1)
# (34, 'Honda', 'Civic', 2019, 32000, 1)
# (35, 'Honda', 'Civic', 2019, 32000, 1)
# (36, 'Honda', 'Civic', 2019, 32000, 1)
# (37, 'Honda', 'Accord', 2020, 38000, 1)
# (38, 'Honda', 'Accord', 2020, 38000, 1)
# (39, 'Honda', 'Accord', 2020, 38000, 1)
# (40, 'Honda', 'Accord', 2020, 38000, 1)
# Please enter a number between 1 and 6.
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:4
#
#         1.Rent a car on hourly basis costs $5
#         2.Rent a car on daily  basis costs $20
#         3.Rent a car on weekly basis costs $60
#
# How would you like to rent?0
# Please enter a valid number.
# How would you like to rent?0
# Please enter a valid number.
# How would you like to rent?0
# Please enter a valid number.
# How would you like to rent?1
# Which brand would you like to rent?
# 0.Toyota
# 1.Honda
# 2.Mazda
# Please pick from the list: 0
# Which model would you like to rent?
# 0.Lexus
# 1.Corolla
# 2.CHR
# 3.Venza
# Please pick from the list: 0
# Please choose the year?
# 0.2020
# 1.2021
# Please pick from the list: 0
# How many cars would you like to rent?1
#
#  ***** Thank you Walt Disney for renting with us! *****
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:5
# 1
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:2
#
#  *****  Thank you Walt Disney for being a loyal customer. *****
# Here is your bill:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#  RentDate  :2023-03-23 00:15:39.129981
#  ReturDate :2023-04-01 20:06:29.844918
#  RentalBasis :Hourly
#  Number of cars: 1
#  Total payment:1180
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:3
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:4
#
#         1.Rent a car on hourly basis costs $5
#         2.Rent a car on daily  basis costs $20
#         3.Rent a car on weekly basis costs $60
#
# How would you like to rent?2
# Which brand would you like to rent?
# 0.Toyota
# 1.Honda
# 2.Mazda
# Please pick from the list: 0
# Which model would you like to rent?
# 0.Lexus
# 1.Corolla
# 2.CHR
# 3.Venza
# Please pick from the list: 0
# Please choose the year?
# 0.2020
# 1.2021
# Please pick from the list: 0
# How many cars would you like to rent?2
#
#  ***** Thank you Walt Disney for renting with us! *****
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:5
# 2
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:2
#
#  *****  Thank you Walt Disney for being a loyal customer. *****
# Here is your bill:
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#  RentDate  :2023-03-23 00:15:39.129981
#  ReturDate :2023-04-01 20:07:02.973576
#  RentalBasis :Daily
#  Number of cars: 2
#  Total payment:360
# =-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
#         1.Return the car by Car_Id.
#         2.Return all.
#         3.Exit.
#
# Enter your choice:3
#
#         -=-=-=-=-=-=-=- Welcome to the Canada Rental Shop -=-=-=-=-=-=-=-=-=-
#         How can we help you?
#         1.Display all cars.
#         2.Display all available cars.
#         3.Display all type of rents.
#         4.Rent a car.
#         5.Return a car.
#         6.Exit.
#
# Enter your choice:6

# %%
CanCarRental.cars
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2592\2234400310.py in <module>
# ----> 1 CanCarRental.cars
#
# NameError: name 'CanCarRental' is not defined

# %%
selected_car={'make': 'Toyota', 'model': 'Lexux', 'year': 2020, 'number_of_cars': 2}

# %%
 ls = list(filter(lambda item:item[1]==selected_car["make"]and item[2]==selected_car["model"] and item[3]==selected_car["year"] ,CanCarRental.cars))

# %%
ls
# Out:
# [(1, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (2, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (3, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (4, 'Toyota', 'Lexux', 2020, 35000, 1),
#  (5, 'Toyota', 'Lexux', 2020, 35000, 1)]
